# %%
import pandas as pd

# troque pelo nome do seu arquivo
df = pd.read_parquet("zikavirus_2020.parquet", engine="fastparquet")

print(df.shape) 
print(df.info())
print(df.head())
# Out:
# (20867, 42)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20867 entries, 0 to 20866
# Data columns (total 42 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tp_not      20867 non-null  object
#  1   id_agravo   20867 non-null  object
#  2   cs_suspeit  0 non-null      float64
#  3   dt_notific  20867 non-null  object
#  4   sem_not     20867 non-null  object
#  5   nu_ano      20867 non-null  object
#  6   sg_uf_not   20867 non-null  object
#  7   id_municip  20867 non-null  object
#  8   id_regiona  17423 non-null  object
#  9   dt_sin_pri  20867 non-null  object
#  10  sem_pri     20867 non-null  object
#  11  nu_idade_n  20867 non-null  object
#  12  cs_sexo     20867 non-null  object
#  13  cs_gestant  20865 non-null  object
#  14  cs_raca     20867 non-null  object
#  15  cs_escol_n  18101 non-null  object
#  16  sg_uf       20866 non-null  object
#  17  id_mn_resi  20866 non-null  object
# ...
